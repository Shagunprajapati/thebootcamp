# %%
string="Python is easy"
rev=string[::-1]
print(rev)
words=string.split()
rev_words=" ".join(words[::-1])
print(rev_words)
# Out:
# ysae si nohtyP
# easy is Python

# %%
numbers=[5,6,7,10,30]
for i in numbers:
  if(i%2==0):
     print(i)
# Out:
# 6
# 10
# 30
